# %% [markdown]
# # Introduction

# %% [markdown]
# - Webscrape https://www.tennislive.net for pro-level match data

# %% [markdown]
# ### Install Packages

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ### Check Status Code
# - 200 = success
# - 404 = failed

# %% [markdown]
# ### Insert Player Profile Link

# %%
url = 'https://www.tennislive.net/atp/novak-djokovic/'
page = requests.get(url)
page.status_code
# Out:
# 200

# %% [markdown]
# ### Extract Match Data

# %%
def extract_match_data(urls):
    data_list = []
    
    for url in urls:
        # Fetch HTML content from the URL
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract match information
        date = soup.find('td', class_='w50').text.strip().split(' ')[0]
        round_info = soup.find_all('td', class_='w50')[1].text.strip()
        player1 = soup.find_all('td', class_='w130')[0].text.strip()
        player2 = soup.find_all('td', class_='w130')[1].text.strip()
        score = soup.find('span', id='score').text.strip()
        tournament = soup.find('td', class_='w200').find('a').text.strip()
        
        # Extract statistics function
        def extract_statistic(statistic):
            row = soup.find('td', string=statistic).parent
            player1_stat = row.find_all('td')[1].text.strip().split(' ')[0]
            player2_stat = row.find_all('td')[2].text.strip().split(' ')[0]
            return player1_stat, player2_stat
        
        # List of statistics to extract
        statistics = [
            '1st SERVE %',
            '1st SERVE POINTS WON',
            '2nd SERVE POINTS WON',
            'TOTAL RETURN POINTS WON',
            'TOTAL POINTS WON',
            'DOUBLE FAULTS',
            'ACES'
        ]

        # List of statistics to extract 
        stats_length = len(soup.find_all('td', class_='info_txt'))

        if stats_length == 8:
            statistics.insert(3, 'BREAK POINTS WON')  # Insert 'BREAK POINTS WON' at the correct position
        
        # Extract statistics for original players
        stat_data = {}
        table = soup.find_all('table', class_ = 'table_stats_match')

        if len(table) > 0 and table[0].find('td', class_='info_txt'):  # Process only if the table has data
            for stat in statistics:
                player1_stat, player2_stat = extract_statistic(stat)  # Extract stats for each player
                stat_name = (stat.lower()
                                .replace(' ', '_')
                                .replace('%', 'percentage')
                                .replace('/', '_')
                                .replace('(', '')
                                .replace(')', ''))

                # Store stats in dictionary
                stat_data[f'{stat_name}_player1'] = player1_stat
                stat_data[f'{stat_name}_player2'] = player2_stat
        else:
            # If the table is empty, set all stats to None
            for stat in statistics:
                stat_name = (stat.lower()
                                .replace(' ', '_')
                                .replace('%', 'percentage')
                                .replace('/', '_')
                                .replace('(', '')
                                .replace(')', ''))

                stat_data[f'{stat_name}_player1'] = None
                stat_data[f'{stat_name}_player2'] = None

        # Append match data to the list
        match_data = {
            'Date': date,
            'Round': round_info,
            'Player 1': player1,
            'Player 2': player2,
            'Score': score,
            'Tournament': tournament,
            **stat_data
        }
        data_list.append(match_data)
    
    # Convert list of dictionaries to DataFrame
    df = pd.DataFrame(data_list)
    
    # Sort DataFrame by Date in descending order
    df['Date'] = pd.to_datetime(df['Date'], format='%d.%m.%y')
    
    df = df.sort_values(by='Date', ascending=True).reset_index(drop=True)
    
    return df

# %% [markdown]
# ### Input individual links HERE
# - optional

# %%
# urls = ['https://www.tennislive.net/atp/match/rudy-quan-VS-jonas-pelle-hartenstein/m15-orange-park-2024/',
#         'https://www.tennislive.net/atp/match/rudy-quan-VS-shintaro-imai/little-rock-challenger-2024/',
#         'https://www.tennislive.net/atp/match/rudy-quan-VS-filip-peliwo/little-rock-challenger-2024/',
#         'https://www.tennislive.net/atp/match/rudy-quan-VS-stefan-kozlov/little-rock-challenger-2024/',
#         'https://www.tennislive.net/atp/match/rudy-quan-VS-andres-andrade/little-rock-challenger-2024/',
#         'https://www.tennislive.net/atp/match/yuta-shimizu-VS-rudy-quan/little-rock-challenger-2024/']

# extract_match_data(urls)

# %% [markdown]
# # Accomodate for Player Profile Page

# %%
def player_profile(url):
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html')
    
    table = soup.find_all('table', class_ = 'table_pmatches')[1]
    rows = table.find_all('td', class_='w50')
    
    
    match_links = []

    for a in table.find_all('a', href=True):
        if "https://www.tennislive.net/atp/match/" in a['href']:
            match_links.append(a['href'])
            
    return extract_match_data(match_links)

# %%
df = player_profile(url)

# %%
df
# Out:
#          Date      Round          Player 1                 Player 2  \
# 0  2023-11-23               Novak Djokovic           Cameron Norrie
# 1  2023-11-25                Jannik Sinner           Novak Djokovic
# 2  2023-12-31               Novak Djokovic            Zhizhen Zhang
# 3  2024-01-02               Novak Djokovic             Jiri Lehecka
# 4  2024-01-03        1/4    Alex De Minaur           Novak Djokovic
# 5  2024-01-14  1st round    Novak Djokovic             Dino Prizmic
# 6  2024-01-17  2nd round    Novak Djokovic           Alexei Popyrin
# 7  2024-01-19  3rd round    Novak Djokovic  Tomas Martin Etcheverry
# 8  2024-01-21  4th round    Novak Djokovic         Adrian Mannarino
# 9  2024-01-23        1/4    Novak Djokovic       Taylor Harry Fritz
# 10 2024-01-26        1/2     Jannik Sinner           Novak Djokovic
# 11 2024-03-09  2nd round    Novak Djokovic         Aleksandar Vukic
# 12 2024-03-11  3rd round        Luca Nardi           Novak Djokovic
# 13 2024-04-09  2nd round    Novak Djokovic          Roman Safiullin
# 14 2024-04-11  3rd round    Novak Djokovic          Lorenzo Musetti
# 15 2024-04-12        1/4    Novak Djokovic           Alex De Minaur
# 16 2024-04-13        1/2       Casper Ruud           Novak Djokovic
# 17 2024-05-10  2nd round    Novak Djokovic          Corentin Moutet
# 18 2024-05-12  3rd round  Alejandro Tabilo           Novak Djokovic
# 19 2024-05-22  2nd round    Novak Djokovic         Yannick Hanfmann
# 20 2024-05-23        1/4    Novak Djokovic        Tallon Griekspoor
# 21 2024-05-24        1/2      Tomas Machac           Novak Djokovic
# 22 2024-05-28  1st round    Novak Djokovic    Pierre-Hugues Herbert
# 23 2024-05-30  2nd round    Novak Djokovic  Roberto Carballes Baena
# 24 2024-06-01  3rd round    Novak Djokovic          Lorenzo Musetti
# 25 2024-06-03  4th round    Novak Djokovic      Francisco Cerundolo
# 26 2024-06-04        1/4       Casper Ruud           Novak Djokovic
# 27 2024-07-02  1st round    Novak Djokovic              Vit Kopriva
# 28 2024-07-04  2nd round    Novak Djokovic           Jacob Fearnley
# 29 2024-07-06  3rd round    Novak Djokovic           Alexei Popyrin
# 30 2024-07-08  4th round    Novak Djokovic              Holger Rune
# 31 2024-07-10        1/4    Novak Djokovic           Alex De Minaur
# 32 2024-07-12        1/2    Novak Djokovic          Lorenzo Musetti
# 33 2024-07-14        fin    Carlos Alcaraz           Novak Djokovic
# 34 2024-07-27  1st round    Novak Djokovic            Matthew Ebden
# 35 2024-07-29  2nd round    Novak Djokovic             Rafael Nadal
# 36 2024-07-31  3rd round    Novak Djokovic          Dominik Koepfer
# 37 2024-08-01        1/4    Novak Djokovic       Stefanos Tsitsipas
# 38 2024-08-02        1/2    Novak Djokovic          Lorenzo Musetti
# 39 2024-08-04        fin    Novak Djokovic           Carlos Alcaraz
# 40 2024-08-26  1st round    Novak Djokovic               Radu Albot
# 41 2024-08-28  2nd round    Novak Djokovic              Laslo Djere
# 42 2024-08-30  3rd round    Alexei Popyrin           Novak Djokovic
# 43 2024-09-14               Novak Djokovic            Ioannis Xilas
# 44 2024-10-05  2nd round    Novak Djokovic           Alex Michelsen
# 45 2024-10-08  3rd round    Novak Djokovic           Flavio Cobolli
# 46 2024-10-09  4th round    Novak Djokovic          Roman Safiullin
# 47 2024-10-11        1/4    Novak Djokovic             Jakub Mensik
# 48 2024-10-12        1/2    Novak Djokovic       Taylor Harry Fritz
# 49 2024-10-13        fin     Jannik Sinner           Novak Djokovic
#
#                           Score    Tournament 1st_serve_percentage_player1  \
# 0                      6-4, 6-4     Davis Cup                        27/48
# 1                 6-2, 2-6, 7-5     Davis Cup                       67/105
# 2                      6-3, 6-2     Australia                        28/46
# 3                6-1, 6-73, 6-1     Australia                        49/80
# 4                      6-4, 6-4     Australia                        34/49
# 5           6-2, 6-75, 6-3, 6-4     Melbourne                       77/129
# 6           6-3, 4-6, 7-64, 6-3     Melbourne                       73/119
# 7                6-3, 6-3, 7-62     Melbourne                        57/84
# 8                 6-0, 6-0, 6-3     Melbourne                        48/69
# 9           7-63, 4-6, 6-2, 6-3     Melbourne                       72/115
# 10          6-1, 6-2, 6-76, 6-3     Melbourne                       64/110
# 11                6-2, 5-7, 6-3  Indian Wells                        46/76
# 12                6-4, 3-6, 6-3  Indian Wells                        64/90
# 13                     6-1, 6-2   Monte-Carlo                        22/34
# 14                     7-5, 6-3   Monte-Carlo                        46/67
# 15                     7-5, 6-4   Monte-Carlo                        42/64
# 16                6-4, 1-6, 6-4   Monte-Carlo                        44/78
# 17                     6-3, 6-1          Rome                        26/42
# 18                     6-2, 6-3          Rome                        30/42
# 19                     6-3, 6-3        Geneva                        45/68
# 20                     7-5, 6-1        Geneva                        38/53
# 21                6-4, 0-6, 6-1        Geneva                        46/75
# 22               6-4, 7-63, 6-4         Paris                        56/82
# 23                6-4, 6-1, 6-2         Paris                        46/73
# 24     7-5, 6-76, 2-6, 6-3, 6-0         Paris                       90/139
# 25      6-1, 5-7, 3-6, 7-5, 6-3         Paris                      123/183
# 26                  - walk over         Paris                         None
# 27                6-1, 6-2, 6-2        London                        39/58
# 28           6-3, 6-4, 5-7, 7-5        London                       82/123
# 29          4-6, 6-3, 6-4, 7-63        London                       78/113
# 30                6-3, 6-4, 6-2        London                        51/80
# 31                  - walk over        London                         None
# 32               6-4, 7-62, 6-4        London                       69/103
# 33               6-2, 6-2, 7-64        London                        56/95
# 34                     6-0, 6-1         Paris                        18/30
# 35                     6-1, 6-4         Paris                        29/47
# 36                     7-5, 6-3         Paris                        36/56
# 37                    6-3, 7-63         Paris                        57/80
# 38                     6-4, 6-2         Paris                        36/55
# 39                   7-63, 7-62         Paris                        69/93
# 40                6-2, 6-2, 6-4      New York                        39/83
# 41  6-4, 6-4, 2-0,    - retired      New York                        42/89
# 42           6-4, 6-4, 2-6, 6-4      New York                       74/127
# 43                     6-0, 6-1     Davis Cup                         None
# 44                   7-63, 7-69      Shanghai                        52/76
# 45                     6-1, 6-2      Shanghai                        24/40
# 46                     6-3, 6-2      Shanghai                        33/51
# 47               6-74, 6-1, 6-4      Shanghai                        52/82
# 48                    6-4, 7-66      Shanghai                        50/71
# 49                    7-64, 6-3      Shanghai                        41/67
#
#    1st_serve_percentage_player2 1st_serve_points_won_player1  \
# 0                         53/75                        24/27
# 1                         46/77                        48/67
# 2                         35/57                        24/28
# 3                         47/75                        36/49
# 4                         43/68                        33/34
# 5                        84/123                        51/77
# 6                        64/111                        60/73
# 7                        72/100                        49/57
# 8                         34/58                        39/48
# 9                        90/154                        59/72
# 10                       79/116                        53/64
# 11                       56/100                        38/46
# 12                        57/95                        44/64
# 13                        26/61                        17/22
# 14                        33/62                        31/46
# 15                        30/71                        27/42
# 16                        46/79                        28/44
# 17                        45/59                        17/26
# 18                        27/52                        23/30
# 19                        42/50                        32/45
# 20                        32/55                        33/38
# 21                        60/92                        27/46
# 22                       65/102                        47/56
# 23                        48/78                        33/46
# 24                       87/145                        62/90
# 25                       95/146                       85/123
# 26                         None                         None
# 27                        53/96                        35/39
# 28                       80/122                        66/82
# 29                       98/133                        69/78
# 30                        43/80                        38/51
# 31                         None                         None
# 32                       82/111                        52/69
# 33                       71/101                        47/56
# 34                        26/43                        15/18
# 35                        42/58                        23/29
# 36                        39/59                        31/36
# 37                        47/71                        37/57
# 38                        38/65                        23/36
# 39                        65/98                        54/69
# 40                        67/93                        29/39
# 41                        43/73                        33/42
# 42                       76/130                        55/74
# 43                         None                         None
# 44                        59/86                        40/52
# 45                        35/55                        20/24
# 46                        24/43                        29/33
# 47                       65/109                        43/52
# 48                        49/84                        39/50
# 49                        38/58                        31/41
#
#    1st_serve_points_won_player2  ... total_return_points_won_player1  \
# 0                         35/53  ...                           30/75
# 1                         35/46  ...                           24/77
# 2                         24/35  ...                           26/57
# 3                         30/47  ...                           36/75
# 4                         30/43  ...                           27/68
# 5                         55/84  ...                          56/123
# 6                         47/64  ...                          37/111
# 7                         51/72  ...                          39/100
# 8                         17/34  ...                           33/58
# 9                         59/90  ...                          64/154
# 10                        53/79  ...                          46/116
# 11                        44/56  ...                          44/100
# 12                        44/57  ...                           35/95
# 13                        16/26  ...                           34/61
# 14                        20/33  ...                           30/62
# 15                        18/30  ...                           33/71
# 16                        31/46  ...                           29/79
# 17                        21/45  ...                           33/59
# 18                        19/27  ...                           22/52
# 19                        24/42  ...                           23/50
# 20                        23/32  ...                           23/55
# 21                        38/60  ...                           43/92
# 22                        46/65  ...                          37/102
# 23                        23/48  ...                           43/78
# 24                        51/87  ...                          64/145
# 25                        58/95  ...                          56/146
# 26                         None  ...                            None
# 27                        29/53  ...                           50/96
# 28                        59/80  ...                          41/122
# 29                        72/98  ...                          45/133
# 30                        30/43  ...                           32/80
# 31                         None  ...                            None
# 32                        50/82  ...                          49/111
# 33                        47/71  ...                          42/101
# 34                        11/26  ...                           27/43
# 35                        23/42  ...                           30/58
# 36                        27/39  ...                           24/59
# 37                        29/47  ...                           32/71
# 38                        22/38  ...                           33/65
# 39                        47/65  ...                           35/98
# 40                        39/67  ...                           44/93
# 41                        28/43  ...                           34/73
# 42                        54/76  ...                          51/130
# 43                         None  ...                            None
# 44                        43/59  ...                           32/86
# 45                        20/35  ...                           29/55
# 46                        15/24  ...                           20/43
# 47                        51/65  ...                          43/109
# 48                        35/49  ...                           30/84
# 49                        29/38  ...                           17/58
#
#    total_return_points_won_player2 total_points_won_player1  \
# 0                             8/48                   70/123
# 1                           40/105                   89/182
# 2                            10/46                   62/103
# 3                            25/80                   91/155
# 4                             8/49                   68/117
# 5                           46/129                  139/252
# 6                           32/119                  124/230
# 7                            19/84                  104/184
# 8                            17/69                   85/127
# 9                           31/115                  148/269
# 10                          28/110                  128/226
# 11                           22/76                   98/176
# 12                           33/90                   92/185
# 13                            6/34                    62/95
# 14                           25/67                   72/129
# 15                           24/64                   73/135
# 16                           34/78                   73/157
# 17                           14/42                   61/101
# 18                           10/42                    54/94
# 19                           24/68                   67/118
# 20                           13/53                   63/108
# 21                           34/75                   84/167
# 22                           16/82                  103/184
# 23                           24/73                   92/151
# 24                          53/139                  150/284
# 25                          68/183                  171/329
# 26                            None                     None
# 27                           10/58                   98/154
# 28                          34/123                  130/245
# 29                          23/113                  135/246
# 30                           21/80                   91/160
# 31                            None                     None
# 32                          36/103                  116/214
# 33                           28/95                  109/196
# 34                            5/30                    52/73
# 35                           15/47                   63/105
# 36                           14/56                   66/115
# 37                           30/80                   82/151
# 38                           20/55                   68/120
# 39                           27/93                  101/191
# 40                           29/83                   98/176
# 41                           33/89                   90/162
# 42                          48/127                  130/257
# 43                            None                     None
# 44                           21/76                   87/162
# 45                            7/40                    62/95
# 46                           13/51                    58/94
# 47                           22/82                  103/191
# 48                           19/71                   82/155
# 49                           19/67                   65/125
#
#    total_points_won_player2 double_faults_player1 double_faults_player2  \
# 0                    53/123                     1                     1
# 1                    93/182                     5                     1
# 2                    41/103                     1                     2
# 3                    64/155                     2                     1
# 4                    49/117                     2                     1
# 5                   113/252                     1                     7
# 6                   106/230                     0                     4
# 7                    80/184                     0                     1
# 8                    42/127                     5                     0
# 9                   121/269                     3                     2
# 10                   98/226                     1                     4
# 11                   78/176                     5                     3
# 12                   93/185                     7                     1
# 13                    33/95                     0                     2
# 14                   57/129                     2                     1
# 15                   62/135                     1                     4
# 16                   84/157                     4                     2
# 17                   40/101                     0                     0
# 18                    40/94                     0                     5
# 19                   51/118                     2                     0
# 20                   45/108                     1                     5
# 21                   83/167                     2                     2
# 22                   81/184                     2                     7
# 23                   59/151                     1                     3
# 24                  134/284                     2                     2
# 25                  158/329                     2                     2
# 26                     None                  None                  None
# 27                   56/154                     2                     5
# 28                  115/245                     3                     5
# 29                  111/246                     3                     4
# 30                   69/160                     2                     4
# 31                     None                  None                  None
# 32                   98/214                     4                     1
# 33                   87/196                     6                     4
# 34                    21/73                     0                     4
# 35                   43/103                     1                     2
# 36                   49/115                     0                     2
# 37                   69/151                     1                     3
# 38                   52/120                     1                     2
# 39                   90/191                     2                     1
# 40                   78/176                    10                     3
# 41                   72/162                     8                     1
# 42                  127/257                     6                    14
# 43                     None                  None                  None
# 44                   75/162                     3                     0
# 45                    33/95                     2                     1
# 46                    36/94                     1                     2
# 47                   88/191                     1                     6
# 48                   73/155                     0                     5
# 49                   60/125                     0                     0
#
#    aces_player1 aces_player2 break_points_won_player1 break_points_won_player2
# 0             8            4                      NaN                      NaN
# 1            12            6                      3/4                      2/9
# 2             7            4                      NaN                      NaN
# 3             3            4                     6/11                      2/5
# 4             7            4                      NaN                      NaN
# 5            11            7                     8/17                      4/9
# 6            11           17                     3/11                      2/7
# 7            10           13                      NaN                      NaN
# 8            17            1                     7/11                      0/3
# 9            20           16                     4/21                      2/6
# 10            9            7                      NaN                      NaN
# 11           11            9                     5/13                      2/6
# 12            6            4                     3/11                      2/4
# 13            1            1                      NaN                      NaN
# 14            3            1                      5/6                      3/6
# 15            2            3                     5/11                      3/7
# 16            4            3                      4/7                      4/5
# 17            1            0                      6/9                      2/7
# 18            4            8                      NaN                      NaN
# 19            3            3                      4/9                     1/11
# 20            4            4                      4/9                      0/7
# 21            4            4                     5/12                     4/11
# 22            4            7                      3/7                      1/1
# 23            5            2                     7/12                      2/3
# 24            5            1                     9/15                      5/5
# 25            6            3                     6/11                     4/19
# 26         None         None                      NaN                      NaN
# 27           10            4                      NaN                      NaN
# 28           14           13                      4/7                      2/6
# 29           19           19                      2/8                      1/2
# 30            5            3                     4/14                      0/2
# 31         None         None                      NaN                      NaN
# 32            6            2                     4/13                      2/4
# 33            5            8                     5/14                      1/3
# 34            4            1                      NaN                      NaN
# 35            5            1                     5/12                      2/3
# 36            5            7                      3/4                      1/2
# 37            6            3                      3/6                      2/6
# 38            3            0                     5/13                      2/4
# 39            1            1                      0/6                      0/8
# 40            8            2                     6/16                      1/3
# 41            3           11                     4/10                      1/8
# 42           15           16                     5/12                     4/16
# 43         None         None                      NaN                      NaN
# 44            7           10                      2/7                      2/5
# 45            3            3                      NaN                      NaN
# 46            4            2                      3/5                      0/3
# 47            7           17                      4/9                      1/1
# 48            7            6                      1/9                      0/2
# 49            8            4                      NaN                      NaN
#
# [50 rows x 22 columns]

# %%
df.to_csv('player.csv', index=False)
