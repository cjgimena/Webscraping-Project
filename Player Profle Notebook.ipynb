# %% [markdown]
# # Introduction

# %% [markdown]
# - Webscrape https://www.tennislive.net for pro-level match data
# - Output two .csv files
#     - Single row dataframe for summary statistics dashboard
#     - point by point (Pbp) level csv file for Match Viewer website => to attach timestamps using website tagger

# %% [markdown]
# ### Install Packages

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ### Check Status Code
# - 200 = success
# - 404 = failed

# %%
url = 'https://www.tennislive.net/atp/govind-nanda/'
page = requests.get(url)
page.status_code
# Out:
# 200

# %% [markdown]
# ### Extract Match Data

# %%
def extract_match_data(urls):
    data_list = []
    
    for url in urls:
        # Fetch HTML content from the URL
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract match information
        date = soup.find('td', class_='w50').text.strip().split(' ')[0]
        round_info = soup.find_all('td', class_='w50')[1].text.strip()
        player1 = soup.find_all('td', class_='w130')[0].text.strip()
        player2 = soup.find_all('td', class_='w130')[1].text.strip()
        score = soup.find('span', id='score').text.strip()
        tournament = soup.find('td', class_='w200').find('a').text.strip()
        
        # Extract statistics function
        def extract_statistic(statistic):
            row = soup.find('td', string=statistic).parent
            player1_stat = row.find_all('td')[1].text.strip().split(' ')[0]
            player2_stat = row.find_all('td')[2].text.strip().split(' ')[0]
            return player1_stat, player2_stat
        
        # List of statistics to extract
        statistics = [
            '1st SERVE %',
            '1st SERVE POINTS WON',
            '2nd SERVE POINTS WON',
            'TOTAL RETURN POINTS WON',
            'TOTAL POINTS WON',
            'DOUBLE FAULTS',
            'ACES'
        ]

        # List of statistics to extract 
        stats_length = len(soup.find_all('td', class_='info_txt'))

        if stats_length == 8:
            statistics.insert(3, 'BREAK POINTS WON')  # Insert 'BREAK POINTS WON' at the correct position
        
        # Extract statistics for original players
        stat_data = {}
        table = soup.find_all('table', class_ = 'table_stats_match')

        if len(table) > 0 and table[0].find('td', class_='info_txt'):  # Process only if the table has data
            for stat in statistics:
                player1_stat, player2_stat = extract_statistic(stat)  # Extract stats for each player
                stat_name = (stat.lower()
                                .replace(' ', '_')
                                .replace('%', 'percentage')
                                .replace('/', '_')
                                .replace('(', '')
                                .replace(')', ''))

                # Store stats in dictionary
                stat_data[f'{stat_name}_player1'] = player1_stat
                stat_data[f'{stat_name}_player2'] = player2_stat
        else:
            # If the table is empty, set all stats to None
            for stat in statistics:
                stat_name = (stat.lower()
                                .replace(' ', '_')
                                .replace('%', 'percentage')
                                .replace('/', '_')
                                .replace('(', '')
                                .replace(')', ''))

                stat_data[f'{stat_name}_player1'] = None
                stat_data[f'{stat_name}_player2'] = None

        # Append match data to the list
        match_data = {
            'Date': date,
            'Round': round_info,
            'Player 1': player1,
            'Player 2': player2,
            'Score': score,
            'Tournament': tournament,
            **stat_data
        }
        data_list.append(match_data)
    
    # Convert list of dictionaries to DataFrame
    df = pd.DataFrame(data_list)
    
    # Sort DataFrame by Date in descending order
    df['Date'] = pd.to_datetime(df['Date'], format='%d.%m.%y')
    
    df = df.sort_values(by='Date', ascending=True).reset_index(drop=True)
    
    return df

# %% [markdown]
# ### Input individual links HERE
# - optional

# %%
# urls = ['https://www.tennislive.net/atp/match/rudy-quan-VS-jonas-pelle-hartenstein/m15-orange-park-2024/',
#         'https://www.tennislive.net/atp/match/rudy-quan-VS-shintaro-imai/little-rock-challenger-2024/',
#         'https://www.tennislive.net/atp/match/rudy-quan-VS-filip-peliwo/little-rock-challenger-2024/',
#         'https://www.tennislive.net/atp/match/rudy-quan-VS-stefan-kozlov/little-rock-challenger-2024/',
#         'https://www.tennislive.net/atp/match/rudy-quan-VS-andres-andrade/little-rock-challenger-2024/',
#         'https://www.tennislive.net/atp/match/yuta-shimizu-VS-rudy-quan/little-rock-challenger-2024/']

# extract_match_data(urls)

# %% [markdown]
# # Accomodate for Player Profile Page

# %%
def player_profile(url):
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html')
    
    table = soup.find_all('table', class_ = 'table_pmatches')[1]
    rows = table.find_all('tod', class_='w50')
    
    
    match_links = []

    for a in table.find_all('a', href=True):
        if "https://www.tennislive.net/atp/match/" in a['href']:
            match_links.appe`nd(a['href'])
            
    return extract_match_data(match_links)

# %%
df = player_profile(url)
# Out:
#          Date      Round                Player 1                     Player 2  \
# 0  2022-10-27  2nd round        Alexis Galarneau                 Govind Nanda
# 1  2023-01-06  1st round            Learner Tien                 Govind Nanda
# 2  2023-01-25  1st round            Govind Nanda         Huzaifa Abdul Rehman
# 3  2023-01-26  2nd round          Matthew Segura                 Govind Nanda
# 4  2023-04-17      qual.  Federico Agustin Gomez                 Govind Nanda
# 5  2023-04-17        q 1            Govind Nanda                    Aidan Kim
# 6  2023-04-23        q 1            Govind Nanda                Isaiah Strode
# 7  2023-04-24      qual.          Kyrian Jacquet                 Govind Nanda
# 8  2023-05-02  1st round            Govind Nanda                 Thomas Brown
# 9  2023-05-04  2nd round            Govind Nanda         Huzaifa Abdul Rehman
# 10 2023-05-05        1/4     Roberto Cid Subervi                 Govind Nanda
# 11 2023-06-07  1st round        Alexander Kotzen                 Govind Nanda
# 12 2024-06-12  1st round              Liam Draxl                 Govind Nanda
# 13 2024-06-19  1st round            Govind Nanda                Jerry Roddick
# 14 2024-06-20  2nd round            Govind Nanda               Bruno Kuzuhara
# 15 2024-06-21        1/4           Bernard Tomic                 Govind Nanda
# 16 2024-07-01        q 1            Govind Nanda                Abraham Asaba
# 17 2024-07-02      qual.            Govind Nanda                  Jelani Sarr
# 18 2024-07-03  1st round            Govind Nanda             Alexander Petrov
# 19 2024-07-04  2nd round            Govind Nanda                  Noah Zamora
# 20 2024-07-05        1/4            Govind Nanda                 Jack Anthrop
# 21 2024-07-06        1/2            Govind Nanda                   Karue Sell
# 22 2024-07-07        fin            Govind Nanda              Stefan Dostanic
# 23 2024-07-10  1st round            Govind Nanda  Alan Fernando Rubio Fierros
# 24 2024-07-11  2nd round            Govind Nanda                  Arda Azkara
# 25 2024-07-12        1/4            Govind Nanda                    Kyle Kang
# 26 2024-07-13        1/2            Govind Nanda                     Karl Lee
# 27 2024-07-14        fin            Learner Tien                 Govind Nanda
# 28 2024-07-21        q 1             Tung-Lin Wu                 Govind Nanda
# 29 2024-07-29        q 1  Rodrigo Pacheco Mendez                 Govind Nanda
# 30 2024-08-06  1st round             Tyler Stice                 Govind Nanda
# 31 2024-09-10  1st round            Kaylan Bigun                 Govind Nanda
# 32 2024-09-15        q 1   Jack Pinnington Jones                 Govind Nanda
# 33 2024-09-22        q 1            Govind Nanda              Cannon Kingsley
# 34 2024-09-23      qual.            Govind Nanda                Ryan Peniston
# 35 2024-09-24  1st round        Ernesto Escobedo                 Govind Nanda
# 36 2024-09-29        q 1            Govind Nanda                   Bor Artnak
# 37 2024-09-30      qual.            Govind Nanda               Patrick Zahraj
# 38 2024-10-01  1st round            Learner Tien                 Govind Nanda
# 39 2024-10-06        q 1            Keegan Smith                 Govind Nanda
# 40 2024-10-13        q 1            Govind Nanda            Collin Altamirano
# 41 2024-10-14      qual.            Govind Nanda               Patrick Zahraj
# 42 2024-10-15  1st round            Govind Nanda                   Tim Handel
# 43 2024-10-17  2nd round            Govind Nanda           James Kent Trotter
# 44 2024-10-18        1/4            Govind Nanda             Maks Kasnikowski
# 45 2024-10-19        1/2            Govind Nanda                   Liam Draxl
# 46 2024-10-20        fin          Murphy Cassone                 Govind Nanda
# 47 2024-10-22  1st round            Govind Nanda          Nishesh Basavareddy
# 48 2024-10-23  2nd round              Ozan Baris                 Govind Nanda
# 49 2024-10-30  1st round           Chris Rodesch                 Govind Nanda
#
#                      Score                  Tournament  \
# 0   6-1, 2-1,    - retired                   Las Vegas
# 1          6-1, 6-75, 11-9                  M25 Malibu
# 2                 6-4, 6-4                  M25 Wesley
# 3           2-6, 7-63, 6-1                  M25 Wesley
# 4                 6-1, 6-4      Tallahassee Challenger
# 5                 6-4, 6-2      Tallahassee Challenger
# 6           2-6, 7-62, 6-3         Savannah Challenger
# 7                 7-5, 6-1         Savannah Challenger
# 8           7-64, 2-6, 6-3                  M15 Orange
# 9                 6-3, 6-2                  M15 Orange
# 10                6-2, 6-3                  M15 Orange
# 11                7-5, 6-1                     M15 San
# 12                6-1, 6-3                 M25 Wichita
# 13           4-6, 6-4, 6-3                   M25 Tulsa
# 14               7-65, 6-2                   M25 Tulsa
# 15                6-3, 6-1                   M25 Tulsa
# 16                6-1, 6-3                M15 Lakewood
# 17               6-4, 7-65                M15 Lakewood
# 18           4-6, 6-0, 6-1                M15 Lakewood
# 19                6-2, 6-2                M15 Lakewood
# 20                6-4, 6-4                M15 Lakewood
# 21                6-4, 6-1                M15 Lakewood
# 22           6-4, 5-7, 7-5                M15 Lakewood
# 23                6-4, 6-2                M15 Lakewood
# 24  6-2, 2-0,    - retired                M15 Lakewood
# 25         4-6, 7-62, 7-67                M15 Lakewood
# 26           2-6, 7-5, 6-2                M15 Lakewood
# 27                6-3, 6-3                M15 Lakewood
# 28                6-2, 6-4          Chicago Challenger
# 29                6-0, 6-3        Lexington Challenger
# 30                6-4, 6-4               M25 Southaven
# 31                6-4, 6-4                   Las Vegas
# 32           6-1, 2-6, 6-2         Columbus Challenger
# 33                6-3, 6-3       Charleston Challenger
# 34                6-4, 6-4       Charleston Challenger
# 35                6-2, 6-4       Charleston Challenger
# 36                6-4, 6-2          Tiburon Challenger
# 37  6-4, 3-1,    - retired          Tiburon Challenger
# 38               7-67, 6-1          Tiburon Challenger
# 39          6-4, 5-7, 7-65        Fairfield Challenger
# 40               7-61, 6-2          Calgary Challenger
# 41                7-5, 6-0          Calgary Challenger
# 42                6-4, 6-2          Calgary Challenger
# 43           3-6, 6-4, 6-2          Calgary Challenger
# 44         7-65, 6-75, 7-5          Calgary Challenger
# 45                6-2, 6-4          Calgary Challenger
# 46           4-6, 6-3, 6-4          Calgary Challenger
# 47                6-4, 6-4                 Sioux Falls
# 48               7-64, 6-4                 Sioux Falls
# 49                6-4, 6-3  Charlottesville Challenger
#
#    1st_serve_percentage_player1 1st_serve_percentage_player2  \
# 0                         14/28                        26/34
# 1                          None                         None
# 2                         53/82                        52/82
# 3                         57/90                        56/90
# 4                         29/62                        34/48
# 5                         43/73                        37/83
# 6                        64/100                        43/88
# 7                         30/59                        30/53
# 8                        61/100                        64/84
# 9                         31/50                        27/48
# 10                        35/53                        42/69
# 11                        33/50                        39/58
# 12                        33/44                        29/47
# 13                        60/98                        53/88
# 14                        56/82                        68/83
# 15                        33/70                        28/48
# 16                         None                         None
# 17                         None                         None
# 18                        38/61                        57/88
# 19                        47/71                        37/65
# 20                        37/55                        44/63
# 21                        27/41                        39/74
# 22                       74/113                       63/103
# 23                        39/61                        37/60
# 24                        17/30                        19/45
# 25                       87/124                       81/117
# 26                       71/116                        51/83
# 27                        38/59                        36/62
# 28                        35/60                        35/52
# 29                        24/48                        33/54
# 30                        45/75                        43/73
# 31                        26/52                        48/75
# 32                        48/85                        58/96
# 33                        28/56                        31/56
# 34                        34/53                        34/64
# 35                        40/67                        52/80
# 36                        44/70                        37/60
# 37                        22/39                        29/48
# 38                        38/70                        31/62
# 39                       80/118                       64/104
# 40                        26/58                        25/67
# 41                        32/45                        30/53
# 42                        26/51                        37/59
# 43                        39/64                        53/91
# 44                       72/127                       66/118
# 45                        27/58                        33/51
# 46                        53/88                        47/87
# 47                        37/66                        33/62
# 48                        44/70                        59/99
# 49                         None                         None
#
#    1st_serve_points_won_player1 1st_serve_points_won_player2  ...  \
# 0                         10/14                        10/26  ...
# 1                          None                         None  ...
# 2                         33/53                        31/52  ...
# 3                         36/57                        31/56  ...
# 4                         26/29                        20/34  ...
# 5                         33/43                        23/37  ...
# 6                         39/64                        30/43  ...
# 7                         19/30                        16/30  ...
# 8                         41/61                        45/64  ...
# 9                         22/31                        15/27  ...
# 10                        20/35                        16/42  ...
# 11                        25/33                        23/39  ...
# 12                        22/33                        14/29  ...
# 13                        40/60                        29/53  ...
# 14                        39/56                        41/68  ...
# 15                        27/33                        16/28  ...
# 16                         None                         None  ...
# 17                         None                         None  ...
# 18                        28/38                        26/57  ...
# 19                        31/47                        18/37  ...
# 20                        26/37                        29/44  ...
# 21                        24/27                        22/39  ...
# 22                        47/74                        37/63  ...
# 23                        25/39                        22/37  ...
# 24                        10/17                        10/19  ...
# 25                        57/87                        49/81  ...
# 26                        40/71                        24/51  ...
# 27                        29/38                        19/36  ...
# 28                        22/35                        24/35  ...
# 29                        20/24                        19/33  ...
# 30                        28/45                        25/43  ...
# 31                        20/26                        32/48  ...
# 32                        37/48                        33/58  ...
# 33                        18/28                        21/31  ...
# 34                        19/34                        22/34  ...
# 35                        28/40                        32/52  ...
# 36                        29/44                        22/37  ...
# 37                        17/22                        18/29  ...
# 38                        30/38                        21/31  ...
# 39                        48/80                        50/64  ...
# 40                        21/26                        16/25  ...
# 41                        27/32                        22/30  ...
# 42                        21/26                        23/37  ...
# 43                        25/39                        36/53  ...
# 44                        50/72                        41/66  ...
# 45                        22/27                        19/33  ...
# 46                        37/53                        35/47  ...
# 47                        22/37                        22/33  ...
# 48                        26/44                        36/59  ...
# 49                         None                         None  ...
#
#    total_return_points_won_player1 total_return_points_won_player2  \
# 0                            20/34                           10/28
# 1                             None                            None
# 2                            38/82                           33/82
# 3                            45/90                           40/90
# 4                            24/48                           22/62
# 5                            39/83                           25/73
# 6                            36/88                          41/100
# 7                            27/53                           24/59
# 8                            28/84                          37/100
# 9                            24/48                           16/50
# 10                           39/69                           24/53
# 11                           26/58                           12/50
# 12                           27/47                           15/44
# 13                           42/88                           42/98
# 14                           36/83                           30/82
# 15                           24/48                           27/70
# 16                            None                            None
# 17                            None                            None
# 18                           49/88                           22/61
# 19                           34/65                           28/71
# 20                           24/63                           18/55
# 21                           34/74                            9/41
# 22                          43/103                          43/113
# 23                           31/60                           24/61
# 24                           25/45                            9/30
# 25                          48/117                          49/124
# 26                           42/83                          56/116
# 27                           30/62                           19/59
# 28                           24/52                           21/60
# 29                           28/54                           13/48
# 30                           39/73                           33/75
# 31                           32/75                           14/52
# 32                           43/96                           34/85
# 33                           29/56                           22/56
# 34                           34/64                           24/53
# 35                           37/80                           22/67
# 36                           31/60                           28/70
# 37                           22/48                           12/39
# 38                           26/62                           24/70
# 39                          32/104                          44/118
# 40                           33/67                           15/58
# 41                           29/53                           11/45
# 42                           28/59                           15/51
# 43                           38/91                           23/64
# 44                          46/118                          50/127
# 45                           25/51                           22/58
# 46                           36/87                           33/88
# 47                           24/62                           23/66
# 48                           49/99                           30/70
# 49                            None                            None
#
#    total_points_won_player1 total_points_won_player2 double_faults_player1  \
# 0                     38/62                    24/62                     1
# 1                      None                     None                  None
# 2                    87/164                   77/164                     1
# 3                    95/180                   85/180                     6
# 4                    64/110                   46/110                     6
# 5                    87/156                   69/156                     1
# 6                    95/188                   93/188                     0
# 7                    62/112                   50/112                     5
# 8                    91/184                   93/184                     0
# 9                     58/98                    40/98                     0
# 10                   68/122                   54/122                     1
# 11                   64/108                   44/108                     0
# 12                    56/91                    35/91                     0
# 13                   98/186                   88/186                     2
# 14                   88/165                   77/165                     1
# 15                   67/118                   51/118                     2
# 16                     None                     None                  None
# 17                     None                     None                  None
# 18                   88/149                   61/149                     0
# 19                   77/136                   59/136                     4
# 20                   61/118                   57/118                     1
# 21                   66/115                   49/115                     1
# 22                  113/216                  103/216                     2
# 23                   68/121                   53/121                     2
# 24                    46/75                    29/75                     1
# 25                  123/241                  118/241                     5
# 26                  102/199                   97/199                     2
# 27                   70/121                   51/121                     0
# 28                   63/112                   49/112                     4
# 29                   63/102                   39/102                     5
# 30                   81/148                   67/148                     2
# 31                   70/127                   57/127                     4
# 32                   94/181                   87/181                     6
# 33                   63/112                   49/112                     0
# 34                   63/117                   54/117                     0
# 35                   82/147                   65/147                     2
# 36                   73/130                   57/130                     6
# 37                    49/87                    38/87                     1
# 38                   72/132                   60/132                     4
# 39                  106/222                  116/222                     2
# 40                   76/125                   49/125                     2
# 41                    63/98                    35/98                     0
# 42                   64/110                   46/110                     4
# 43                   79/155                   76/155                     2
# 44                  123/245                  122/245                     5
# 45                   61/109                   48/109                     1
# 46                   91/175                   84/175                     3
# 47                   67/128                   61/128                     1
# 48                   89/169                   80/169                     0
# 49                     None                     None                  None
#
#    double_faults_player2 aces_player1 aces_player2 break_points_won_player1  \
# 0                      0            1            2                      4/8
# 1                   None         None         None                      NaN
# 2                      3            1            3                     4/15
# 3                      5            0            2                     6/11
# 4                      1            4            0                      4/8
# 5                      9            2            0                      3/6
# 6                      5            1            4                      4/9
# 7                      2            1            2                      5/7
# 8                      4           10            1                      2/3
# 9                      4            4            0                      5/9
# 10                     0            2            0                     7/14
# 11                     2            2            1                      4/9
# 12                     1            1            3                      6/8
# 13                     5           11            6                     7/13
# 14                     2            5            1                      3/5
# 15                     1            7            0                      5/7
# 16                  None         None         None                      NaN
# 17                  None         None         None                      NaN
# 18                     7            4            3                     8/13
# 19                     1            0            1                     5/13
# 20                     1            5            1                      3/7
# 21                     3            1            3                      NaN
# 22                     5            1            5                     5/10
# 23                     5            1            0                     5/10
# 24                     4            1            0                      3/8
# 25                     1            1            1                      4/9
# 26                     1            2            2                     7/11
# 27                     1            2            1                      4/8
# 28                     3            2            4                      4/6
# 29                     1            0            0                      4/4
# 30                     1            0            1                     6/12
# 31                     3            2            2                     3/12
# 32                     0            5            4                     4/14
# 33                     2            2            7                      5/8
# 34                     4            2            2                     7/13
# 35                     2            9            4                      3/8
# 36                     3            4            1                      5/8
# 37                     1            1            0                      3/5
# 38                     2            6            2                      3/5
# 39                     4           11            2                      3/6
# 40                     6            0            3                      4/6
# 41                     9            2            6                      5/8
# 42                     6            4            1                      4/8
# 43                     7            1            9                     5/11
# 44                     2            6            6                      5/7
# 45                     4            3            2                     5/10
# 46                     1            5            5                      5/9
# 47                     4            2            4                      3/5
# 48                     3            0            1                     4/11
# 49                  None         None         None                      NaN
#
#    break_points_won_player2
# 0                       1/2
# 1                       NaN
# 2                      2/14
# 3                      5/11
# 4                       1/4
# 5                       0/7
# 6                      5/12
# 7                       2/4
# 8                       3/8
# 9                       2/3
# 10                      3/6
# 11                      0/1
# 12                      2/3
# 13                     5/11
# 14                      1/7
# 15                     1/10
# 16                      NaN
# 17                      NaN
# 18                     3/10
# 19                      1/8
# 20                      1/1
# 21                      NaN
# 22                     4/12
# 23                      2/6
# 24                      0/3
# 25                      5/8
# 26                     6/21
# 27                      1/4
# 28                      1/4
# 29                      0/3
# 30                     4/11
# 31                      1/2
# 32                      2/7
# 33                      2/3
# 34                      5/6
# 35                      0/2
# 36                      2/9
# 37                      1/1
# 38                      1/3
# 39                      3/9
# 40                      2/6
# 41                      1/1
# 42                      1/2
# 43                      3/3
# 44                     4/12
# 45                      2/5
# 46                      4/9
# 47                      1/1
# 48                      3/6
# 49                      NaN
#
# [50 rows x 22 columns]

# %% [markdown]
# # Output the Point Visuals csv

# %%
# Save point_df to CSV file

# Assuming point_df is your DataFrame and player1Name and player2Name are the names from the first row
player1NameNoSpace = df.iloc[0]['player1Name'].replace(" ", "")
player2NameNoSpace = df.iloc[0]['player2Name'].replace(" ", "")

# Save DataFrame to CSV file with modified player names
df.to_csv(f'Point_Visuals_{player1NameNoSpace}_{player2NameNoSpace}.csv', index=False)
